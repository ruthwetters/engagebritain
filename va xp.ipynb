# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_csv("/Users/ruthwetters/Documents/GitHub/russian-troll-tweets/IRAhandle_tweets_1.csv")

# %%
df
# Out:
#         external_author_id           author  \
# 0       906000000000000000           10_GOP
# 1       906000000000000000           10_GOP
# 2       906000000000000000           10_GOP
# 3       906000000000000000           10_GOP
# 4       906000000000000000           10_GOP
# ...                    ...              ...
# 243886          2497991305  AUSTINLOVESBEER
# 243887          2497991305  AUSTINLOVESBEER
# 243888          2497991305  AUSTINLOVESBEER
# 243889          2497991305  AUSTINLOVESBEER
# 243890          2497991305  AUSTINLOVESBEER
#
#                                                   content         region  \
# 0       "We have a sitting Democrat US Senator on tria...        Unknown
# 1       Marshawn Lynch arrives to game in anti-Trump s...        Unknown
# 2       Daughter of fallen Navy Sailor delivers powerf...        Unknown
# 3       JUST IN: President Trump dedicates Presidents ...        Unknown
# ...

# %%
f = plt.figure(figsize=(20,8))
sns.set(style='darkgrid')
df['account_category'].value_counts().plot(kind="pie")
plt.title('account_category')
plt.show()

# %%
pd.isnull(df).sum()
# Out:
# external_author_id         0
# author                     0
# content                    0
# region                    38
# language                   0
# publish_date               0
# harvested_date             0
# following                  0
# followers                  0
# updates                    0
# post_type              89299
# account_type               0
# retweet                    0
# account_category           0
# new_june_2018              0
# alt_external_id            0
# tweet_id                   0
# article_url                0
# tco1_step1             63371
# tco2_step1            177459
# tco3_step1            241088
# dtype: int64

# %%
f = plt.figure(figsize=(20,8))
sns.set(style='darkgrid')
df['region'].value_counts().plot(kind="pie")
plt.title('region')
plt.show()

# %%
#unique values
#target_names = df['Subject discipline'].unique()
#print(target_names)

# %%
df.describe()
# Out:
#        external_author_id      following      followers        updates  \
# count        2.438910e+05  243891.000000  243891.000000  243891.000000
# mean         2.406736e+17    2008.342079    2256.398219    6433.557208
# std          3.921357e+17    3625.387602    4781.906074    9520.379342
# min          3.497640e+07       0.000000       0.000000       1.000000
# 25%          1.679279e+09     149.000000     140.000000    1052.000000
# 50%          2.500690e+09     939.000000     611.000000    2759.000000
# 75%          8.390000e+17    2284.000000    2186.000000    7603.000000
# max          9.681310e+17   21843.000000   23890.000000   70028.000000
#
#              retweet  new_june_2018  alt_external_id      tweet_id
# count  243891.000000  243891.000000     2.438910e+05  2.438910e+05
# mean        0.633857       0.208913     2.406777e+17  7.809279e+17
# std         0.481750       0.406533     3.921440e+17  9.915623e+16
# ...

# %%
#need to derive year?

# %%
plt.figure(figsize=(20,5))
sns.set(style='darkgrid')
arr=np.array([df['publish_date']])
plt.hist(df['publish_date'])#need to bin by decade!
plt.title('date order')
plt.show()

# %%
RightTrolls = df[df['account_category']==('RightTroll')]

# %%
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)

def show_wordcloud(data, title = None):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stopwords,
        max_words=1000,
        max_font_size=40, 
        scale=3,
        random_state=1
    ).generate(str(data))

    fig = plt.figure(1, figsize=(12, 12))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()

show_wordcloud(RightTrolls['content'])

# %%
LeftTrolls = df[df['account_category']==('LeftTroll')]

# %%
show_wordcloud(LeftTrolls['content'])

# %%
RightTrolls = df[df['account_category']==('RightTroll')]

# %%
print('# of edges: {}'.format(g.number_of_edges()))
print('# of nodes: {}'.format(g.number_of_nodes()))
# Out:
# # of edges: 171002
# # of nodes: 22470

# %%
# Define node positions data structure (dict) for plotting
node_positions = {node[0]: (node[1]['id'], -node[1]) for node in g.nodes(data=True)}

# Preview of node_positions with a bit of hack (there is no head/slice method for dictionaries).
dict(list(node_positions.items())[0:5])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-82821e94000c> in <module>
#       1 # Define node positions data structure (dict) for plotting
# ----> 2 node_positions = {node[0]: (node[1]['id'], -node[1]) for node in g.nodes(data=True)}
#       3
#       4 # Preview of node_positions with a bit of hack (there is no head/slice method for dictionaries).
#       5 dict(list(node_positions.items())[0:5])
#
# <ipython-input-47-82821e94000c> in <dictcomp>(.0)
#       1 # Define node positions data structure (dict) for plotting
# ----> 2 node_positions = {node[0]: (node[1]['id'], -node[1]) for node in g.nodes(data=True)}
#       3
#       4 # Preview of node_positions with a bit of hack (there is no head/slice method for dictionaries).
#       5 dict(list(node_positions.items())[0:5])
#
# KeyError: 'id'

# %%
plt.figure(figsize=(8, 6))
nx.draw(g, node_size=10, node_color='black')
plt.title('Graph Representation of Sleeping Giant Trail Map', size=15)
plt.show()
